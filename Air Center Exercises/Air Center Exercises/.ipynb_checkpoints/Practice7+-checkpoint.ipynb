# %% [markdown]
# ![0.jfif](attachment:0.jfif)

# %% [markdown]
# # Logistic Regression Project

# %% [markdown]
# <div style="direction:rtl">
# خب، خب، در این پروژه قصد داریم با کار روی دیتاست یک شرکت تبلیغاتی، این که کاربر روی تبلیغی که به او نمایش داده شده کلیک می کند یا خیر را پیش بینی کنیم.

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# <div style="direction:rtl">
# کتابخانه های مورد نیاز را ایمپورت کنید.

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get the Data

# %% [markdown]
# <div style="direction:rtl">
# دیتاست مورد نظر را فرخوانی کنید و نگاه خلاصه ای به آن بیندازید و همچنین اطلاعات کلی و آماری آن را نمایش دهید.

# %%
df = pd.read_csv(r'G:\courses\AI\air center\1 - Data Science & Machine Learning - AIR Center\Exercises\Datasets for exercising\Practices Datasets\Practice 7\advertising.csv')

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# 1  2016-04-04 01:39:02              0
# 2  2016-03-13 20:35:42              0
# 3  2016-01-10 02:31:19              0
# 4  2016-06-03 03:36:18              0

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
a = ss.fit_transform(df[['Age', 'Daily Time Spent on Site']])
b = pd.DataFrame(a)
b.columns = ['Age', 'Daily Time Spent on Site']

b.describe()
# Out:
#                 Age  Daily Time Spent on Site
# count  1.000000e+03              1.000000e+03
# mean  -3.019807e-17             -4.192202e-16
# std    1.000500e+00              1.000500e+00
# min   -1.936986e+00             -2.044733e+00
# 25%   -7.981854e-01             -8.608147e-01
# 50%   -1.149050e-01              2.028817e-01
# 75%    6.822554e-01              8.549520e-01
# max    2.845977e+00              1.667949e+00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
df.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# 75%              218.792500     1.000000        1.00000
# max              269.960000     1.000000        1.00000

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# <div style="direction:rtl">
# حالا کمی در دیتاست گشت و گذار کنیم تا ببینیم به چه اطلاعاتی دست پیدا می کنیم.

# %% [markdown]
# <div style="direction:rtl">
# برای شروع، نمودار توزیع آماری را بر حسب سن رسم می کنیم.

# %%
sns.set_style('whitegrid')
#sns.set_palette('BrBG')

# %%
df['Age'].hist(bins=40)
# Out:
# <AxesSubplot: >

# %%
sns.histplot(x='Age', data=df, kde=True)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %%
plt.hist(df['Age'])
# Out:
# (array([ 50., 118., 195., 159., 153., 138.,  77.,  65.,  28.,  17.]),
#  array([19. , 23.2, 27.4, 31.6, 35.8, 40. , 44.2, 48.4, 52.6, 56.8, 61. ]),
#  <BarContainer object of 10 artists>)

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# 1  2016-04-04 01:39:02              0
# 2  2016-03-13 20:35:42              0
# 3  2016-01-10 02:31:19              0
# 4  2016-06-03 03:36:18              0

# %%
sns.heatmap(df.drop(columns=['Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country', 'Timestamp']), yticklabels=False)
# Out:
# <AxesSubplot: >

# %%
sns.pairplot(df)

# %% [markdown]
# <div style="direction:rtl">
# جوینت پلات درآمد بر حسب سن را رسم می کنیم.

# %%
sns.jointplot(y='Area Income', x='Age', data=df)

# %% [markdown]
# <div style="direction:rtl">
# KDE پلات میزان وقت گذاشته شده روی سایت تبلیغ بر حسب سن را رسم می کنیم.

# %%
sns.kdeplot(x='Age', y='Daily Time Spent on Site', data=df, fill=True)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Daily Time Spent on Site'>

# %%
sns.jointplot(x='Age', y='Daily Time Spent on Site', data=df, kind='kde', fill=True)

# %% [markdown]
# <div style="direction:rtl">
# جوینت پلات میزان استفاده از اینترنت بر حسب میزان وقت گذاشته شده روی سایت تبلیغ را رسم می کنیم.

# %%
sns.jointplot(y='Daily Internet Usage', x='Daily Time Spent on Site', data=df)

# %% [markdown]
# <div style="direction:rtl">
# در نهایت یک Pain Plot کلی برای دیتاست، با مشخص کردن تفاوت کسانی که روی تبلیغ کلیک کرده اند و نکرده اند را رسم کنید.

# %%
sns.pairplot(df, hue='Clicked on Ad')

# %% [markdown]
# <div style="direction:rtl">
# سعی کنید نتایج بالا را در چند خط تحلیل کنید :

# %% [markdown]
# <div style="direction:rtl">
# تحلیل :

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# <div style="direction:rtl">
# پس از ایمپورت متد مربوطه، داده ها را به دو بخش فیچر و لیبل تقسیم کنید و سپس آن ها را به دو بخش ترین و تست تقسیم نمایید.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

X = df[['Daily Time Spent on Site', 'Age', 'Area Income', 'Daily Internet Usage', 'Male']]
Y = df['Clicked on Ad']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=101)

# %% [markdown]
# <div style="direction:rtl">
# حالا کلاس رگرسیون لاجستیک را بارگزاری نمایید و یک مدل از آن نوع بسازید و با داده های ترین آموزش دهید.

# %%
log_model = LogisticRegression()
log_model.fit(x_train, y_train)
# Out:
# <bound method BaseEstimator._get_param_names of <class 'sklearn.linear_model._logistic.LogisticRegression'>>

# %% [markdown]
# ## Predictions and Evaluations

# %% [markdown]
# <div style="direction:rtl">
# حالا به کمک مدلی که آموزش داده اید، برای داده های تست پیش بینی کنید که کدام یک روی تبلیغ ها کلیک می کنند.

# %%
(log_model.predict(x_test) == y_test).value_counts()
predictions = log_model.predict(x_test)

# %% [markdown]
# <div style="direction:rtl">
# حالا برای مدلی که آموزش داده اید، معیار های ارزیابی همچون Score و Confusion Matrix و Classification Report را بررسی کنید.

# %%
from sklearn.metrics import f1_score, confusion_matrix, classification_report

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       157
#            1       0.94      0.90      0.92       143
#
#     accuracy                           0.93       300
#    macro avg       0.93      0.93      0.93       300
# weighted avg       0.93      0.93      0.93       300

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[149,   8],
#        [ 14, 129]], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       162
#            1       0.96      0.85      0.90       168
#
#     accuracy                           0.91       330
#    macro avg       0.91      0.91      0.91       330
# weighted avg       0.91      0.91      0.91       330

# %% [markdown]
# <div style="direction:rtl">
#
# ## سلام پیش گوی اعظم :)
# <div style="direction:rtl">
#
# #### حالا دیگه می تونی این مدلو برداری ببری به شرکتا بفروشی تا از قبل از نمایش یه تبلیغ به یه کاربر بتونن پیش بینی کنن روش کلیک می کنه یا نه و خب اگه قراره نکنه نشونش  ندن و با یه تبلیغ دیگه جایگزین کنن.
